# %% [markdown]
# # Padding and Stride

# %%
# !pip install mxnet
# Out:
# Requirement already satisfied: mxnet in /Users/wendywang/opt/anaconda3/lib/python3.9/site-packages (1.9.1)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in /Users/wendywang/opt/anaconda3/lib/python3.9/site-packages (from mxnet) (0.8.4)
# Requirement already satisfied: requests<3,>=2.20.0 in /Users/wendywang/opt/anaconda3/lib/python3.9/site-packages (from mxnet) (2.27.1)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /Users/wendywang/opt/anaconda3/lib/python3.9/site-packages (from mxnet) (1.22.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/wendywang/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/wendywang/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/wendywang/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/wendywang/opt/anaconda3/lib/python3.9/site-packages (from requests<3,>=2.20.0->mxnet) (2021.10.8)

# %%
from mxnet import nd
from mxnet.gluon import nn

# Takes convolution operation and applies it to X
def comp_conv2d(conv2d, X):
    conv2d.initialize()
    # Add two extra empty dimensions to X
    X = X.reshape((1, 1) + X.shape)
    Y = conv2d(X)
    return Y.reshape(Y.shape[2:])

# %% [markdown]
# ## Padding

# %%
conv2d = nn.Conv2D(1, kernel_size=3, padding=1)
X = nd.random.uniform(shape=(8, 8))
# Padding of 1 leaves shape unchanged for 3x3 convolution
comp_conv2d(conv2d, X).shape
# Out:
# (8, 8)

# %% [markdown]
# ## Strides

# %%
conv2d = nn.Conv2D(1, kernel_size=3, padding=1, strides=2)
comp_conv2d(conv2d, X).shape
# Out:
# (4, 4)

# %% [markdown]
# ## Asymmetric kernels, padding and strides
#
# We can use different strides, different kernel sizes and different padding for height and width. This can be used, e.g. to adjust the size to a desired shape (4:3 to 1:1).

# %%
# pad only vertically and use different strides on the 8x8 image
conv2d = nn.Conv2D(1, kernel_size=(3, 5), padding=(0, 1), strides=(3, 4))
comp_conv2d(conv2d, X).shape
# Out:
# (2, 2)
