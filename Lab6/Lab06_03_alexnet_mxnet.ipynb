# %% [markdown]
# ## MNIST-AlexNet-MXNet
#
# Use it on scaled-up 224x224 dimensional Fashion-MNIST with 10 class output.

# %%
from mxnet import autograd, gluon, init, nd
from mxnet.gluon import data as gdata, nn
from mxnet.gluon import loss as gloss
import mxnet as mx
import os
import sys
import time

# %%
net = nn.Sequential()
# Use a larger 11 x 11 window to capture objects. Stride of 4 to reduce size.
# The number of output channels is much larger than that in LeNet.
net.add(nn.Conv2D(96, kernel_size=11, strides=4, activation='relu'),
        nn.MaxPool2D(pool_size=3, strides=2),
        # Make the convolution window smaller, set padding to 2 for consistent height/width
        nn.Conv2D(256, kernel_size=5, padding=2, activation='relu'),
        nn.MaxPool2D(pool_size=3, strides=2),
        # Use three successive convolutional layers and a smaller convolution window. 
        nn.Conv2D(384, kernel_size=3, padding=1, activation='relu'),
        nn.Conv2D(384, kernel_size=3, padding=1, activation='relu'),
        nn.Conv2D(256, kernel_size=3, padding=1, activation='relu'),
        # Reduce dimensionality
        nn.MaxPool2D(pool_size=3, strides=2),
        # Expensive dense layer
        nn.Dense(4096, activation="relu"), nn.Dropout(0.5),
        nn.Dense(4096, activation="relu"), nn.Dropout(0.5),
        # Output layer. Since we are using Fashion-MNIST, n = 10
        nn.Dense(10))

# %% [markdown]
# We construct a single-channel data instance with both height and width of 224 to observe the output shape of each layer. It matches our diagram above.

# %%
X = nd.random.uniform(shape=(1, 1, 224, 224))
net.initialize()
for layer in net:
    X = layer(X)
    print(layer.name, 'output shape:\t', X.shape)
# Out:
# conv0 output shape:	 (1, 96, 54, 54)
# pool0 output shape:	 (1, 96, 26, 26)
# conv1 output shape:	 (1, 256, 26, 26)
# pool1 output shape:	 (1, 256, 12, 12)
# conv2 output shape:	 (1, 384, 12, 12)
# conv3 output shape:	 (1, 384, 12, 12)
# conv4 output shape:	 (1, 256, 12, 12)
# pool2 output shape:	 (1, 256, 5, 5)
# dense0 output shape:	 (1, 4096)
# dropout0 output shape:	 (1, 4096)
# dense1 output shape:	 (1, 4096)
# dropout1 output shape:	 (1, 4096)
# dense2 output shape:	 (1, 10)

# %% [markdown]
# ### Reading Data

# %%
def load_data_fashion_mnist(batch_size, resize=None, root=os.path.join(
        '~', '.mxnet', 'datasets', 'fashion-mnist')):
    root = os.path.expanduser(root)  # Expand the user path '~'.
    transformer = []
    if resize:
        transformer += [gdata.vision.transforms.Resize(resize)]
    transformer += [gdata.vision.transforms.ToTensor()]
    transformer = gdata.vision.transforms.Compose(transformer)
    mnist_train = gdata.vision.FashionMNIST(root=root, train=True)
    mnist_test = gdata.vision.FashionMNIST(root=root, train=False)
    num_workers = 0 if sys.platform.startswith('win32') else 4
    train_iter = gdata.DataLoader(
        mnist_train.transform_first(transformer), batch_size, shuffle=True,
        num_workers=num_workers)
    test_iter = gdata.DataLoader(
        mnist_test.transform_first(transformer), batch_size, shuffle=False,
        num_workers=num_workers)
    return train_iter, test_iter

batch_size = 128
train_iter, test_iter = load_data_fashion_mnist(batch_size, resize=224)

# %% [markdown]
# ## Training

# %%
def evaluate_accuracy(data_iter, net, ctx):
    acc_sum, n = nd.array([0], ctx=ctx), 0
    for X, y in data_iter:
        # If ctx is the GPU, copy the data to the GPU.
        X, y = X.as_in_context(ctx), y.as_in_context(ctx).astype('float32')
        acc_sum += (net(X).argmax(axis=1) == y).sum()
        n += y.size
    return acc_sum.asscalar() / n

def train(net, train_iter, test_iter, batch_size, trainer, ctx,
              num_epochs):
    print('training on', ctx)
    loss = gloss.SoftmaxCrossEntropyLoss()
    for epoch in range(num_epochs):
        train_l_sum, train_acc_sum, n, start = 0.0, 0.0, 0, time.time()
        for X, y in train_iter:
            X, y = X.as_in_context(ctx), y.as_in_context(ctx)
            with autograd.record():
                y_hat = net(X)
                l = loss(y_hat, y).sum()
            l.backward()
            trainer.step(batch_size)
            y = y.astype('float32')
            train_l_sum += l.asscalar()
            train_acc_sum += (y_hat.argmax(axis=1) == y).sum().asscalar()
            n += y.size
        test_acc = evaluate_accuracy(test_iter, net, ctx)
        print('epoch %d, loss %.4f, train acc %.3f, test acc %.3f, '
              'time %.1f sec'
              % (epoch + 1, train_l_sum / n, train_acc_sum / n, test_acc,
                 time.time() - start))

# %% [markdown]
# Compared to LeNet the main change is the smaller learning rate and much slower progress due to much larger images.

# %%
lr, num_epochs, ctx = 0.01, 5, mx.gpu()
net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
train(net, train_iter, test_iter, batch_size, trainer, ctx, num_epochs)
# Out:
# ---------------------------------------------------------------------------
# MXNetError                                Traceback (most recent call last)
# /Users/wendywang/Desktop/S1_2023_2024/Neural_Network_and_Deep_Learning/Lab6/Lab06_03_alexnet_mxnet.ipynb Cell 11 line <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/wendywang/Desktop/S1_2023_2024/Neural_Network_and_Deep_Learning/Lab6/Lab06_03_alexnet_mxnet.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> lr, num_epochs, ctx = 0.01, 5, mx.gpu()
# ----> <a href='vscode-notebook-cell:/Users/wendywang/Desktop/S1_2023_2024/Neural_Network_and_Deep_Learning/Lab6/Lab06_03_alexnet_mxnet.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> net.initialize(force_reinit=True, ctx=ctx, init=init.Xavier())
#       <a href='vscode-notebook-cell:/Users/wendywang/Desktop/S1_2023_2024/Neural_Network_and_Deep_Learning/Lab6/Lab06_03_alexnet_mxnet.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> trainer = gluon.Trainer(net.collect_params(), 'sgd', {'learning_rate': lr})
#       <a href='vscode-notebook-cell:/Users/wendywang/Desktop/S1_2023_2024/Neural_Network_and_Deep_Learning/Lab6/Lab06_03_alexnet_mxnet.ipynb#X13sZmlsZQ%3D%3D?line=3'>4</a> train(net, train_iter, test_iter, batch_size, trainer, ctx, num_epochs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/gluon/block.py:657, in Block.initialize(self, init, ctx, verbose, force_reinit)
#     640 def initialize(self, init=initializer.Uniform(), ctx=None, verbose=False,
#     641                force_reinit=False):
#     642     """Initializes :py:class:`Parameter` s of this :py:class:`Block` and its children.
#     643     Equivalent to ``block.collect_params().initialize(...)``
#     644
#    (...)
#     655         Whether to force re-initialization if parameter is already initialized.
#     656     """
# --> 657     self.collect_params().initialize(init, ctx, verbose, force_reinit)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/gluon/parameter.py:896, in ParameterDict.initialize(self, init, ctx, verbose, force_reinit)
#     894     init.set_verbosity(verbose=verbose)
#     895 for _, v in self.items():
# --> 896     v.initialize(None, ctx, init, force_reinit=force_reinit)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/gluon/parameter.py:472, in Parameter.initialize(self, init, ctx, default_init, force_reinit)
#     468     raise ValueError("Cannot initialize Parameter '%s' because it has " \
#     469                      "invalid shape: %s."%(self.name, str(self.shape)))
#     471 self._deferred_init = (init, ctx, default_init, None)
# --> 472 self._finish_deferred_init()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/gluon/parameter.py:353, in Parameter._finish_deferred_init(self)
#     349     data = zeros_fn(**kwargs)
#     350     initializer.create(default_init)(
#     351         initializer.InitDesc(self.name, {'__init__': init}), data)
# --> 353 self._init_impl(data, ctx)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/gluon/parameter.py:365, in Parameter._init_impl(self, data, ctx_list)
#     362         dev_list.append(None)
#     363     dev_list[ctx.device_id] = i
# --> 365 self._data = [data.copyto(ctx) for ctx in self._ctx_list]
#     366 self._init_grad()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/gluon/parameter.py:365, in <listcomp>(.0)
#     362         dev_list.append(None)
#     363     dev_list[ctx.device_id] = i
# --> 365 self._data = [data.copyto(ctx) for ctx in self._ctx_list]
#     366 self._init_grad()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/ndarray/ndarray.py:2671, in NDArray.copyto(self, other)
#    2669 elif isinstance(other, Context):
#    2670     hret = NDArray(_new_alloc_handle(self.shape, other, True, self.dtype))
# -> 2671     return _internal._copyto(self, out=hret)
#    2672 else:
#    2673     raise TypeError('copyto does not support type ' + str(type(other)))
#
# File <string>:27, in _copyto(data, out, name, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/_ctypes/ndarray.py:82, in _imperative_invoke(handle, ndargs, keys, vals, out, is_np_op, output_is_list)
#      78 # return output stypes to avoid the c_api call for checking
#      79 # a handle's stype in _ndarray_cls
#      80 out_stypes = ctypes.POINTER(ctypes.c_int)()
# ---> 82 check_call(_LIB.MXImperativeInvokeEx(
#      83     ctypes.c_void_p(handle),
#      84     ctypes.c_int(len(ndargs)),
#      85     c_handle_array(ndargs),
#      86     ctypes.byref(num_output),
#      87     ctypes.byref(output_vars),
#      88     ctypes.c_int(len(keys)),
#      89     c_str_array(keys),
#      90     c_str_array([str(s) for s in vals]),
#      91     ctypes.byref(out_stypes)))
#      93 create_ndarray_fn = _global_var._np_ndarray_cls if is_np_op else _global_var._ndarray_cls
#      94 if original_output is not None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/mxnet/base.py:246, in check_call(ret)
#     235 """Check the return value of C API call.
#     236
#     237 This function will raise an exception when an error occurs.
#    (...)
#     243     return value from API calls.
#     244 """
#     245 if ret != 0:
# --> 246     raise get_last_ffi_error()
#
# MXNetError: Traceback (most recent call last):
#   File "../src/ndarray/ndarray.cc", line 1297
# MXNetError: GPU is not enabled
